# %%
# !pip install -e /Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense --quiet
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !python feedback.py
# Out:
# Starting StructSense processing...
# Starting StructSense flow...
# 2025-04-18 13:59:32,970 - structsense.app - INFO - Starting StructSense flow...
# 2025-04-18 13:59:32,970 - structsense.app - INFO - ####################################################################################################
# 2025-04-18 13:59:32,970 - structsense.app - INFO - Starting True
# 2025-04-18 13:59:32,970 - structsense.app - INFO - ####################################################################################################
# ...
