# %% [markdown]
# # Install

# %%
# !pip install --upgrade structsense --quiet

# %%
# !pip install --upgrade pip --quiet

# %% [markdown]
# # Set environment variables

# %%
import os

# ✅ Preferred way to set environment variables in notebooks or scripts
os.environ["ENABLE_WEIGHTSANDBIAS"] = "false"
os.environ["ENABLE_MLFLOW"] = "false"
os.environ["MLFLOW_TRACKING_URL"] = "http://localhost:8089"
os.environ["ENABLE_KG_SOURCE"] = "true"
os.environ["ONTOLOGY_DATABASE"] = "ontology_database_agent_test1"
os.environ["WEAVIATE_HTTP_HOST"] = "localhost" #default
os.environ["WEAVIATE_HTTP_HOST"] = "localhost" #default
os.environ["WEAVIATE_API_KEY"] = "XFG!NQmUVEC&8" 
os.environ["OLLAMA_API_ENDPOINT"] = "http://host.docker.internal:11434"
os.environ["OLLAMA_MODEL"] = "nomic-embed-text" 
os.environ["EXTERNAL_PDF_EXTRACTION_SERVICE"] = "False"

# %%
# !structsense-cli
# Out:
# Usage: structsense-cli [OPTIONS] COMMAND [ARGS]...
#
#   CLI commands for the Structsense Framework application
#
# Options:
#   --help  Show this message and exit.
#
# Commands:
#   extract  Extract the terms along with sentence.

# %%
# !echo $WEAVIATE_API_KEY $WEAVIATE_HTTP_HOST
# Out:
# XFG!NQmUVEC&8 localhost

# %%
# !ls
# Out:
# crew_memory           ner_config            structsense-cli.ipynb

# %%
# !ls ner_config/
# Out:
# embedding.yaml                 ner_task.yaml
# human_in_loop.yaml             search_ontology_knowledge.yaml
# ner_agent.yaml

# %% [markdown]
# # Extract from a PDF file (with knowledge source)
#
# Input: https://www.biorxiv.org/content/10.1101/2025.03.06.641914v1

# %%
# !structsense-cli extract \
  --agentconfig ner_config/ner_agent.yaml \
  --taskconfig ner_config/ner_task.yaml \
  --embedderconfig ner_config/embedding.yaml \
  --knowledgeconfig ner_config/search_ontology_knowledge.yaml \
  --source /Users/tekrajchhetri/Downloads/data/test.pdf \
  --enable_human_feedback true \
  --agent_feedback_config config/human_in_loop.yaml #optional
# Out:
# 2025-04-17 15:35:33,922 - structsense.cli - INFO - Processing source: /Users/tekrajchhetri/Downloads/data/test.pdf with agent config: ner_config/ner_agent.yaml, task config: ner_config/ner_task.yaml, embedderconfig: ner_config/embedding.yaml, knowledgeconfig: ner_config/search_ontology_knowledge.yaml
# Processing source: /Users/tekrajchhetri/Downloads/data/test.pdf with agent config: ner_config/ner_agent.yaml, task config: ner_config/ner_task.yaml, embedderconfig: ner_config/embedding.yaml knowledgeconfig: ner_config/search_ontology_knowledge.yaml
# 2025-04-17 15:35:33,922 - structsense.app - INFO - Starting StructSense flow...
# 2025-04-17 15:35:33,922 - structsense.app - INFO - ####################################################################################################
# 2025-04-17 15:35:33,922 - structsense.app - INFO - Starting true
# 2025-04-17 15:35:33,922 - structsense.app - INFO - ####################################################################################################
# 2025-04-17 15:35:33,923 - utils.utils - INFO - Trying config paths: ['config/human_in_loop.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/config/human_in_loop.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/config/human_in_loop.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/config/human_in_loop.yaml']
# 2025-04-17 15:35:33,923 - utils.utils - INFO - Trying paths: ['/Users/tekrajchhetri/Downloads/data/test.pdf', '/Users/tekrajchhetri/Downloads/data/test.pdf', '/Users/tekrajchhetri/Downloads/data/test.pdf', '/Users/tekrajchhetri/Downloads/data/test.pdf']
# 2025-04-17 15:35:33,923 - utils.utils - INFO - Using path: /Users/tekrajchhetri/Downloads/data/test.pdf
# 2025-04-17 15:35:33,923 - utils.utils - INFO - Processing single file: /Users/tekrajchhetri/Downloads/data/test.pdf
# 2025-04-17 15:35:38,182 - utils.utils - INFO - Successfully extracted 17 sections
# ╭─────────────────────────────── Flow Execution ───────────────────────────────╮
# │                                                                              │
# │  Starting Flow Execution                                                     │
# │  Name: StructSenseFlow                                                       │
# │  ID: c49cd357-2a1e-45b5-9d6e-7d83dce4472a                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 2025-04-17 15:35:38,190 - structsense.app - INFO - Initializing StructSenseFlow
# 2025-04-17 15:35:38,190 - utils.human_in_loop_handler - INFO - Human-in-the-loop component initialized : True
# 2025-04-17 15:35:38,191 - utils.human_in_loop_handler - INFO - Agent-specific feedback configuration: {'extractor_agent': False, 'alignment_agent': False, 'judge_agent': False, 'humanfeedback_agent': True}
# 2025-04-17 15:35:38,191 - utils.utils - INFO - Trying config paths: ['ner_config/ner_agent.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/ner_agent.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/ner_agent.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/ner_agent.yaml']
# 2025-04-17 15:35:38,206 - utils.utils - INFO - file processing - <_io.TextIOWrapper name='ner_config/ner_agent.yaml' mode='r' encoding='utf-8'>, type: agent
# 2025-04-17 15:35:38,206 - utils.utils - INFO - Trying config paths: ['ner_config/ner_task.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/ner_task.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/ner_task.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/ner_task.yaml']
# 2025-04-17 15:35:38,225 - utils.utils - INFO - file processing - <_io.TextIOWrapper name='ner_config/ner_task.yaml' mode='r' encoding='utf-8'>, type: task
# 2025-04-17 15:35:38,225 - utils.utils - INFO - Trying config paths: ['ner_config/embedding.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/embedding.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/embedding.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/embedding.yaml']
# 2025-04-17 15:35:38,226 - utils.utils - INFO - file processing - <_io.TextIOWrapper name='ner_config/embedding.yaml' mode='r' encoding='utf-8'>, type: embedder
# 2025-04-17 15:35:38,226 - utils.utils - INFO - Trying config paths: ['ner_config/search_ontology_knowledge.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/search_ontology_knowledge.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/search_ontology_knowledge.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_with_human_loop/ner_config/search_ontology_knowledge.yaml']
# 2025-04-17 15:35:38,227 - utils.utils - INFO - file processing - <_io.TextIOWrapper name='ner_config/search_ontology_knowledge.yaml' mode='r' encoding='utf-8'>, type: knowledge
# 2025-04-17 15:35:38,249 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2025-04-17 15:35:38,522 - structsense.app - INFO - Memory systems initialized successfully
# 🌊 Flow: StructSenseFlow
#     ID: c49cd357-2a1e-45b5-9d6e-7d83dce4472a
# └── 🧠 Starting Flow...
#
#  Flow started with ID: c49cd357-2a1e-45b5-9d6e-7d83dce4472a
# 2025-04-17 15:35:38,524 - crewai.flow.flow - INFO - Flow started with ID: c49cd357-2a1e-45b5-9d6e-7d83dce4472a
# 🌊 Flow: StructSenseFlow
#     ID: c49cd357-2a1e-45b5-9d6e-7d83dce4472a
# ├── 🧠 Starting Flow...
# └── 🔄 Running: process_inputs
#
# 2025-04-17 15:35:38,525 - structsense.app - INFO - Starting structured information processing flow
# 2025-04-17 15:35:38,525 - structsense.app - INFO - Updated shared state: process_inputs
# 🌊 Flow: StructSenseFlow
#     ID: c49cd357-2a1e-45b5-9d6e-7d83dce4472a
# ├── Flow Method Step
# └── ✅ Completed: process_inputs
#
# 🌊 Flow: StructSenseFlow
#     ID: c49cd357-2a1e-45b5-9d6e-7d83dce4472a
# ├── Flow Method Step
# ├── ✅ Completed: process_inputs
# └── 🔄 Running: extracted_structured_information
#
# 2025-04-17 15:35:38,527 - structsense.app - INFO - Starting structured information extraction
# 2025-04-17 15:35:38,529 - structsense.app - INFO - Successfully initialized extractor_agent and extraction_task
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 2fa85727-4fe4-47b0-956c-bbf12d3543ce                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 33d088d4-bf5a-4cde-be2b-341925ab3f4a
#        Status: Executing Task...
#
# 2025-04-17 15:35:39,270 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:35:40,028 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 🚀 Crew: crew
# └── 📋 Task: 33d088d4-bf5a-4cde-be2b-341925ab3f4a
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
#
#             Status: In Progress
#
# # Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
# ## Task: From the given literature extract named entities from neuroscience statements.  A named entity is anything that can be referred to with a proper name.  Some common named entities in neuroscience articles are animal species (e.g., mouse, drosophila, zebrafish), anatomical regions (e.g., neocortex, mushroom body, cerebellum), experimental conditions (e.g., control, tetrodotoxin treatment, Scn1a knockout), and cell types (e.g., pyramidal neuron, direction-sensitive mechanoreceptor, oligodendrocyte)
# rtoires. It poses the difficult problem of continuous tracking of multiple agents, including both self and others. To understand how this tracking is implemented neurally, we examined responses of hippocampal neurons while humans performed a joystick-controlled continuous prey-pursuit task involving two simultaneously fleeing prey (and, in some cases, a predator) in a virtual open field. We found neural maps encoding the positions of all the agents. All maps were multiplexed in single neurons and were disambiguated by the use of the population coding principle of semiorthogonal subspaces, which can facilitate cross-agent generalization. Some neurons, more common in the posterior hippocampus, had narrow tuning functions reminiscent of place cells, lower firing rates, and high information per spike; others, which were found in both anterior and posterior hippocampus, had broad tuning functions, higher firing rates, and less information per spike. Semi-orthogonalization was selectively associated with the broadly tuned neurons. These results suggest an answer to the problem of navigational individuation, that is, how mapping codes can distinguish different agents, and establish the neuronavigational foundations of pursuit.', 'publication_date': ''}, 'sections': [{'heading': 'INTRODUCTION', 'content': "['Pursuit is a foraging behavior involving continuous and interactive navigation with the goal of catching a fleeing prey while avoiding predators (Fabian et al., 2018;Olberg et al., 2000;Stephens  Krebs, 1986;Ydenberg  Dill, 1986). It is an archetypal example of continuous decision-making, in which choice and control are deployed simultaneously (Burge et al., 2025;Cisek and Kalaska, 2010;Gordon et al., 2021;Merel et al., 2015;Yoo et al., 2021A). Moment to moment choices during pursuit require tracking the locations of multiple agents at the same time, including the self, pursued prey, and unpursued prey, and navigating towards interception loci.', 'Among regions associated with navigation, the hippocampus is the most well studied (Chersi and Burgess, 2015;Ekstrom et al., 2018;Epstein et al., 2017;Kunz et al., 2021;Maguire et al., 2006;Nyberg et al., 2022;OKeefe and Dostrovsky, 1971;Suthana et al., 2009). The hippocampus contains place cells that track the allocentric position of the self in physical space (Ekstrom et al., 2003;Jacobs et al., 2010;Miller et al., 2013;OKeefe et al., 1998;Wilson and McNaughton, 1993) and virtual space (Harvey et al., 2009;Mackay et al., 2024). The hippocampus also has a variety of other neurons relevant to pursuit (Behrens et al., 2018). These include neurons that are tuned to positions of external (physical) goals (Brown et al., 2016;Gauthier and Tank, 2018;Kunz et al., 2021;Poucet and Hok, 2017;Watrous et al., 2018), and social place cells that track the positions of other agents (Danjo et al., 2018;Forli and Yartsev, 2023;Omer et al., 2018;Rao et al., 2019;Stangl et al., 2021;Zang et al., 2024). The collective existence of these neurons indicates that the hippocampus contains the basic ingredients to track both self and prey in the course of pursuit. However, it does not give insight into how the brain solve the problem of disambiguating representations when faced with multiple distinct agents.', 'The need to distinguish self from others, and to distinguish multiple others, means that the brain must solve the individuation problem. In short, the brain needs a mechanism to know which agent a neurons responses refer to. One possibility would involve labelled line coding, in which separate sets of neurons track each single agent. However, such codes tend to be inflexible and have limited capacity for generalization (Barak et al., 2013;Fine et al., 2023;Fusi et al., 2016). In addition to these theoretical concerns, there are empirical ones: most brain areas contain mixed selective codes rather than labeled line codes (Ebitz and Hayden 2021;Fusi et al., 2016;Rigotti et al., 2013;Tye et al., 2024). One w ...
#
# 🚀 Crew: crew
# └── 📋 Task: 33d088d4-bf5a-4cde-be2b-341925ab3f4a
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
#
#             Status: In Progress
#         └── 🧠 Thinking...
#
# 15:35:40 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= openai/gpt-4o-2024-11-20; provider = openrouter
# 2025-04-17 15:35:40,075 - LiteLLM - INFO -
# LiteLLM completion() model= openai/gpt-4o-2024-11-20; provider = openrouter
# 2025-04-17 15:35:40,368 - httpx - INFO - HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# 15:35:54 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-17 15:35:54,293 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 🚀 Crew: crew
# └── 📋 Task: 33d088d4-bf5a-4cde-be2b-341925ab3f4a
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
#
#             Status: In Progress
#
#
#
# # Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
# ## Final Answer:
# {
#   "extracted_structured_information": {
#     "ANIMAL_SPECIES": [],
#     "ANATOMICAL_REGIONS": [
#       {
#         "entity": "hippocampus",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Among regions associated with navigation, the hippocampus is the most well studied.",
#         "start": 37,
#         "end": 47,
#         "paper_location": "introduction",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus"
#       },
#       {
#         "entity": "posterior hippocampus",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Narrowly tuned neurons were more prevalent in the posterior hippocampus and encoded position more efficiently.",
#         "start": 48,
#         "end": 70,
#         "paper_location": "abstract",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus"
#       },
#       {
#         "entity": "anterior hippocampus",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Others, which were found in both anterior and posterior hippocampus, had broad tuning functions.",
#         "start": 41,
#         "end": 61,
#         "paper_location": "abstract",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus"
#       }
#     ],
#     "EXPERIMENTAL_CONDITIONS": [
#       {
#         "entity": "joystick-controlled continuous prey-pursuit task",
#         "label": "EXPERIMENTAL_CONDITION",
#         "sentence": "To understand how this tracking is implemented neurally, we examined responses of hippocampal neurons while humans performed a joystick-controlled continuous prey-pursuit task involving two simultaneously fleeing prey (and, in some cases, a predator) in a virtual open field.",
#         "start": 79,
#         "end": 128,
#         "paper_location": "abstract",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus"
#       },
#       {
#         "entity": "virtual pursuit task",
#         "label": "EXPERIMENTAL_CONDITION",
#         "sentence": "We recorded populations of neurons in the hippocampus in thirteen humans performing a virtual pursuit task with two prey and (in a subset of participants) a predator.",
#         "start": 72,
#         "end": 93,
#         "paper_location": "introduction",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus"
#       },
#       {
#         "entity": "prey-pursuit task",
#         "label": "EXPERIMENTAL_CONDITION",
#         "sentence": "Human participants (n=13) performed the prey-pursuit task.",
#         "start": 40,
#         "end": 57,
#         "paper_location": "prey pursuit in humans",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus"
#       }
#     ],
#     "CELL_TYPES": [
#       {
#         "entity": "place cells",
#         "label": "CELL_TYPE",
#         "sentence": "The hippocampus contains place cells that track the allocentric position of the self in physical space.",
#         "start": 25,
#         "end": 36,
#         "paper_location": "introduction",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus"
#       },
#       {
#         "entity": "social place cells",
#         "label": "CELL_TYPE",
#         "sentence": "These include neurons that are tuned to positions of external goals and social place cells that track the positions of other agents.",
#         "start": 91,
#         "end": 108,
#         "paper_location": "introduction",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus"
#       }
#     ]
#   }
# }
#
#
# 2025-04-17 15:35:54,476 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 🚀 Crew: crew
# └── 📋 Task: 33d088d4-bf5a-4cde-be2b-341925ab3f4a
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
#
#             Status: In Progress
#         └── 🧠 Thinking...
#
# 15:35:54 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= openai/gpt-4o-2024-11-20; provider = openrouter
# 2025-04-17 15:35:54,502 - LiteLLM - INFO -
# LiteLLM completion() model= openai/gpt-4o-2024-11-20; provider = openrouter
# 2025-04-17 15:35:54,811 - httpx - INFO - HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# 15:36:05 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-17 15:36:05,967 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 🚀 Crew: crew
# └── 📋 Task: 33d088d4-bf5a-4cde-be2b-341925ab3f4a
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
#
#             Status: In Progress
#
# 2025-04-17 15:36:06,028 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,054 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,078 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,099 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,119 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,139 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,158 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,178 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 🚀 Crew: crew
# └── 📋 Task: 33d088d4-bf5a-4cde-be2b-341925ab3f4a
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# └── 📋 Task: 33d088d4-bf5a-4cde-be2b-341925ab3f4a
#        Assigned to: Neuroscience Named Entity Recognition (NER) Extractor Agent
#
#        Status: ✅ Completed
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 33d088d4-bf5a-4cde-be2b-341925ab3f4a                                  │
# │  Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent          │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 2fa85727-4fe4-47b0-956c-bbf12d3543ce                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 2025-04-17 15:36:06,200 - structsense.app - INFO - Updated shared state: extracted_terms
# 2025-04-17 15:36:06,200 - structsense.app - INFO - Extraction complete with 0 terms
# 🌊 Flow: StructSenseFlow
#     ID: c49cd357-2a1e-45b5-9d6e-7d83dce4472a
# ├── Flow Method Step
# ├── ✅ Completed: process_inputs
# └── ✅ Completed: extracted_structured_information
#
# 🌊 Flow: StructSenseFlow
#     ID: c49cd357-2a1e-45b5-9d6e-7d83dce4472a
# ├── Flow Method Step
# ├── ✅ Completed: process_inputs
# ├── ✅ Completed: extracted_structured_information
# └── 🔄 Running: align_structured_information
#
# 2025-04-17 15:36:06,204 - structsense.app - INFO - Starting structured information alignment
# 2025-04-17 15:36:06,206 - structsense.app - INFO - Successfully initialized alignment_agent and alignment_task
# /Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/.venv/lib/python3.11/site-packages/weaviate/warnings.py:340: UserWarning: Con006: You're using the sync client in an async context. This usage is discouraged to avoid blocking your async event loop with sync I/O calls.
#             We encourage you to update your code to use the async client instead when running inside async def functions!
#   warnings.warn(
# 2025-04-17 15:36:06,226 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/meta "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,319 - httpx - INFO - HTTP Request: GET https://pypi.org/pypi/weaviate-client/json "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,365 - utils.utils - INFO - ✅ Successfully connected to Weaviate
# 2025-04-17 15:36:06,371 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/schema/Ontology_database_agent_test1 "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,408 - utils.utils - INFO - Found 3 results for query: 'hippocampus ANATOMICAL_REGION: [Object(uuid=_WeaviateUUIDInt('57790335-00fa-5585-8444-bcca30b7d6e6'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003876', 'all_synonyms_combined': None, 'class_id': 'UBERON_0003876', 'definition': 'A part or parts of the hippocampus that have a particular function.', 'ontology': 'uberon', 'label': 'hippocampal field'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('acfef7ab-8881-5bb6-9c5d-52cdc01918dd'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003342', 'all_synonyms_combined': None, 'class_id': 'UBERON_0003342', 'definition': 'A mucosa that is part of an anal canal [Automatically generated definition].', 'ontology': 'uberon', 'label': 'mucosa of anal canal'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('c05fb998-5401-5901-8493-bbb1d93bde52'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0001876', 'all_synonyms_combined': None, 'definition': 'Subcortical brain region lying anterior to the hippocampal formation in the temporal lobe and anterior to the temporal horn of the lateral ventricle in some species. It is usually subdivided into several groups. Functionally, it is not considered a unitary structure (MM).', 'class_id': 'UBERON_0001876', 'ontology': 'uberon', 'label': 'amygdala'}, references=None, vector={}, collection='Ontology_database_agent_test1')]'
# 2025-04-17 15:36:06,408 - utils.utils - INFO - [{'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003876', 'all_synonyms_combined': None, 'class_id': 'UBERON_0003876', 'definition': 'A part or parts of the hippocampus that have a particular function.', 'ontology': 'uberon', 'label': 'hippocampal field'}, {'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003342', 'all_synonyms_combined': None, 'class_id': 'UBERON_0003342', 'definition': 'A mucosa that is part of an anal canal [Automatically generated definition].', 'ontology': 'uberon', 'label': 'mucosa of anal canal'}, {'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0001876', 'all_synonyms_combined': None, 'definition': 'Subcortical brain region lying anterior to the hippocampal formation in the temporal lobe and anterior to the temporal horn of the lateral ventricle in some species. It is usually subdivided into several groups. Functionally, it is not considered a unitary structure (MM).', 'class_id': 'UBERON_0001876', 'ontology': 'uberon', 'label': 'amygdala'}]
# 2025-04-17 15:36:06,420 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/meta "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,512 - httpx - INFO - HTTP Request: GET https://pypi.org/pypi/weaviate-client/json "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,568 - utils.utils - INFO - ✅ Successfully connected to Weaviate
# 2025-04-17 15:36:06,574 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/schema/Ontology_database_agent_test1 "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,607 - utils.utils - INFO - Found 3 results for query: 'posterior hippocampus ANATOMICAL_REGION: [Object(uuid=_WeaviateUUIDInt('57790335-00fa-5585-8444-bcca30b7d6e6'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003876', 'all_synonyms_combined': None, 'class_id': 'UBERON_0003876', 'definition': 'A part or parts of the hippocampus that have a particular function.', 'ontology': 'uberon', 'label': 'hippocampal field'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('065a5f10-f1d3-51af-bcd4-701a1c1a1039'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0002770', 'all_synonyms_combined': None, 'class_id': 'UBERON_0002770', 'definition': 'The part of the hypothalamus posterior to the middle region consisting of several nuclei including the medial mamillary nucleus, lateral mamillary nucleus, and posterior hypothalamic nucleus (posterior hypothalamic area). The posterior hypothalamic area is concerned with control of sympathetic responses and is sensitive to conditions of decreasing temperature and controls the mechanisms for the conservation and increased production of heat.', 'ontology': 'uberon', 'label': 'posterior hypothalamic region'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('acfef7ab-8881-5bb6-9c5d-52cdc01918dd'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003342', 'all_synonyms_combined': None, 'definition': 'A mucosa that is part of an anal canal [Automatically generated definition].', 'class_id': 'UBERON_0003342', 'ontology': 'uberon', 'label': 'mucosa of anal canal'}, references=None, vector={}, collection='Ontology_database_agent_test1')]'
# 2025-04-17 15:36:06,608 - utils.utils - INFO - [{'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003876', 'all_synonyms_combined': None, 'class_id': 'UBERON_0003876', 'definition': 'A part or parts of the hippocampus that have a particular function.', 'ontology': 'uberon', 'label': 'hippocampal field'}, {'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0002770', 'all_synonyms_combined': None, 'class_id': 'UBERON_0002770', 'definition': 'The part of the hypothalamus posterior to the middle region consisting of several nuclei including the medial mamillary nucleus, lateral mamillary nucleus, and posterior hypothalamic nucleus (posterior hypothalamic area). The posterior hypothalamic area is concerned with control of sympathetic responses and is sensitive to conditions of decreasing temperature and controls the mechanisms for the conservation and increased production of heat.', 'ontology': 'uberon', 'label': 'posterior hypothalamic region'}, {'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003342', 'all_synonyms_combined': None, 'definition': 'A mucosa that is part of an anal canal [Automatically generated definition].', 'class_id': 'UBERON_0003342', 'ontology': 'uberon', 'label': 'mucosa of anal canal'}]
# 2025-04-17 15:36:06,624 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/meta "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,752 - httpx - INFO - HTTP Request: GET https://pypi.org/pypi/weaviate-client/json "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,801 - utils.utils - INFO - ✅ Successfully connected to Weaviate
# 2025-04-17 15:36:06,809 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/schema/Ontology_database_agent_test1 "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,850 - utils.utils - INFO - Found 3 results for query: 'anterior hippocampus ANATOMICAL_REGION: [Object(uuid=_WeaviateUUIDInt('57790335-00fa-5585-8444-bcca30b7d6e6'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003876', 'class_id': 'UBERON_0003876', 'definition': 'A part or parts of the hippocampus that have a particular function.', 'all_synonyms_combined': None, 'ontology': 'uberon', 'label': 'hippocampal field'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('acfef7ab-8881-5bb6-9c5d-52cdc01918dd'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003342', 'all_synonyms_combined': None, 'definition': 'A mucosa that is part of an anal canal [Automatically generated definition].', 'class_id': 'UBERON_0003342', 'ontology': 'uberon', 'label': 'mucosa of anal canal'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('c05fb998-5401-5901-8493-bbb1d93bde52'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0001876', 'all_synonyms_combined': None, 'definition': 'Subcortical brain region lying anterior to the hippocampal formation in the temporal lobe and anterior to the temporal horn of the lateral ventricle in some species. It is usually subdivided into several groups. Functionally, it is not considered a unitary structure (MM).', 'class_id': 'UBERON_0001876', 'ontology': 'uberon', 'label': 'amygdala'}, references=None, vector={}, collection='Ontology_database_agent_test1')]'
# 2025-04-17 15:36:06,850 - utils.utils - INFO - [{'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003876', 'class_id': 'UBERON_0003876', 'definition': 'A part or parts of the hippocampus that have a particular function.', 'all_synonyms_combined': None, 'ontology': 'uberon', 'label': 'hippocampal field'}, {'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0003342', 'all_synonyms_combined': None, 'definition': 'A mucosa that is part of an anal canal [Automatically generated definition].', 'class_id': 'UBERON_0003342', 'ontology': 'uberon', 'label': 'mucosa of anal canal'}, {'class_uri': 'http://purl.obolibrary.org/obo/UBERON_0001876', 'all_synonyms_combined': None, 'definition': 'Subcortical brain region lying anterior to the hippocampal formation in the temporal lobe and anterior to the temporal horn of the lateral ventricle in some species. It is usually subdivided into several groups. Functionally, it is not considered a unitary structure (MM).', 'class_id': 'UBERON_0001876', 'ontology': 'uberon', 'label': 'amygdala'}]
# 2025-04-17 15:36:06,870 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/meta "HTTP/1.1 200 OK"
# 2025-04-17 15:36:06,973 - httpx - INFO - HTTP Request: GET https://pypi.org/pypi/weaviate-client/json "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,042 - utils.utils - INFO - ✅ Successfully connected to Weaviate
# 2025-04-17 15:36:07,047 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/schema/Ontology_database_agent_test1 "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,089 - utils.utils - INFO - Found 3 results for query: 'joystick-controlled continuous prey-pursuit task EXPERIMENTAL_CONDITION: [Object(uuid=_WeaviateUUIDInt('7f000364-6814-5b2a-8fe9-5da121416fa6'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/CL_0000002', 'all_synonyms_combined': None, 'class_id': 'CL_0000002', 'definition': "Obsoleted in July 2013 and replaced by the CLO 'immortal cell line cell' class, as a result of CLO-OBI-CL alignment efforts.\n\nCovers cells actively being cultured or stored in a quiescent state for future use.", 'ontology': 'cl', 'label': 'obsolete immortal cell line cell'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('3d4067ee-0a63-52b0-b712-f282844e390e'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/CL_0000196', 'class_id': 'CL_0000196', 'definition': 'A muscle cell that is involved in the mechanism of insect flight. This encompasses both, cells that power flight and cells that control flight.', 'all_synonyms_combined': None, 'ontology': 'cl', 'label': 'insect flight muscle cell'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('b9660047-71a8-550d-8af7-c7553f867b8b'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/GO_0040012', 'all_synonyms_combined': None, 'class_id': 'GO_0040012', 'definition': 'Any process that modulates the frequency, rate or extent of locomotion of a cell or organism.', 'ontology': 'go', 'label': 'regulation of locomotion'}, references=None, vector={}, collection='Ontology_database_agent_test1')]'
# 2025-04-17 15:36:07,090 - utils.utils - INFO - [{'class_uri': 'http://purl.obolibrary.org/obo/CL_0000002', 'all_synonyms_combined': None, 'class_id': 'CL_0000002', 'definition': "Obsoleted in July 2013 and replaced by the CLO 'immortal cell line cell' class, as a result of CLO-OBI-CL alignment efforts.\n\nCovers cells actively being cultured or stored in a quiescent state for future use.", 'ontology': 'cl', 'label': 'obsolete immortal cell line cell'}, {'class_uri': 'http://purl.obolibrary.org/obo/CL_0000196', 'class_id': 'CL_0000196', 'definition': 'A muscle cell that is involved in the mechanism of insect flight. This encompasses both, cells that power flight and cells that control flight.', 'all_synonyms_combined': None, 'ontology': 'cl', 'label': 'insect flight muscle cell'}, {'class_uri': 'http://purl.obolibrary.org/obo/GO_0040012', 'all_synonyms_combined': None, 'class_id': 'GO_0040012', 'definition': 'Any process that modulates the frequency, rate or extent of locomotion of a cell or organism.', 'ontology': 'go', 'label': 'regulation of locomotion'}]
# 2025-04-17 15:36:07,107 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/meta "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,227 - httpx - INFO - HTTP Request: GET https://pypi.org/pypi/weaviate-client/json "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,265 - utils.utils - INFO - ✅ Successfully connected to Weaviate
# 2025-04-17 15:36:07,270 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/schema/Ontology_database_agent_test1 "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,315 - utils.utils - INFO - Found 3 results for query: 'virtual pursuit task EXPERIMENTAL_CONDITION: [Object(uuid=_WeaviateUUIDInt('5cbfb1eb-bcd6-5ffe-b6a3-09dd687e64a1'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/GO_0048869', 'all_synonyms_combined': None, 'class_id': 'GO_0048869', 'definition': 'A biological process whose specific outcome is the progression of a cell over time from an initial condition to a later condition.', 'ontology': 'go', 'label': 'cellular developmental process'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('b9854fa4-e629-5074-9710-a9a953e2ea2c'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/UBERON_8440011', 'all_synonyms_combined': None, 'definition': 'The part of the cortex that is responsible for processing visual information.', 'class_id': 'UBERON_8440011', 'ontology': 'uberon', 'label': 'cortical visual area'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('308ac523-d030-55fb-bf3b-6fab14843065'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/GO_0090326', 'all_synonyms_combined': None, 'class_id': 'GO_0090326', 'definition': 'Any process that increases the frequency, rate, or extent of the self-propelled movement of a cell or organism from one location to another in a behavioral context; the aspect of locomotory behavior having to do with movement.', 'ontology': 'go', 'label': 'positive regulation of locomotion involved in locomotory behavior'}, references=None, vector={}, collection='Ontology_database_agent_test1')]'
# 2025-04-17 15:36:07,315 - utils.utils - INFO - [{'class_uri': 'http://purl.obolibrary.org/obo/GO_0048869', 'all_synonyms_combined': None, 'class_id': 'GO_0048869', 'definition': 'A biological process whose specific outcome is the progression of a cell over time from an initial condition to a later condition.', 'ontology': 'go', 'label': 'cellular developmental process'}, {'class_uri': 'http://purl.obolibrary.org/obo/UBERON_8440011', 'all_synonyms_combined': None, 'definition': 'The part of the cortex that is responsible for processing visual information.', 'class_id': 'UBERON_8440011', 'ontology': 'uberon', 'label': 'cortical visual area'}, {'class_uri': 'http://purl.obolibrary.org/obo/GO_0090326', 'all_synonyms_combined': None, 'class_id': 'GO_0090326', 'definition': 'Any process that increases the frequency, rate, or extent of the self-propelled movement of a cell or organism from one location to another in a behavioral context; the aspect of locomotory behavior having to do with movement.', 'ontology': 'go', 'label': 'positive regulation of locomotion involved in locomotory behavior'}]
# 2025-04-17 15:36:07,328 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/meta "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,421 - httpx - INFO - HTTP Request: GET https://pypi.org/pypi/weaviate-client/json "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,472 - utils.utils - INFO - ✅ Successfully connected to Weaviate
# 2025-04-17 15:36:07,477 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/schema/Ontology_database_agent_test1 "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,521 - utils.utils - INFO - Found 3 results for query: 'prey-pursuit task EXPERIMENTAL_CONDITION: [Object(uuid=_WeaviateUUIDInt('5cbfb1eb-bcd6-5ffe-b6a3-09dd687e64a1'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/GO_0048869', 'all_synonyms_combined': None, 'definition': 'A biological process whose specific outcome is the progression of a cell over time from an initial condition to a later condition.', 'class_id': 'GO_0048869', 'ontology': 'go', 'label': 'cellular developmental process'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('3bbd4390-b91e-5431-ae9d-aa3c4d6380e4'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'definition': "The specific movement from place to place of an organism in response to external or internal stimuli. Locomotion of a whole organism in a manner dependent upon some combination of that organism's internal state and external conditions.", 'all_synonyms_combined': None, 'class_id': 'GO_0007626', 'class_uri': 'http://purl.obolibrary.org/obo/GO_0007626', 'ontology': 'go', 'label': 'locomotory behavior'}, references=None, vector={}, collection='Ontology_database_agent_test1'), Object(uuid=_WeaviateUUIDInt('d3a02157-8fd8-530c-8fbf-8ebd90129f81'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'class_uri': 'http://purl.obolibrary.org/obo/CL_0000578', 'all_synonyms_combined': None, 'class_id': 'CL_0000578', 'definition': "This class has been re-labeled to imply reference only to in vitro experimentally modified cells, similarly, the definition has been slightly updated to reflect this. 'experimentally modified cell' refers only to cells in vitro, and not modified in vivo/in environment cells. There is currently no class representing unmodified in vitro cells (other than the parent 'cell in vitro'), or a class representing modified native cells. More granular subclassing of experimentally modified cell can be found in ReO. MHB 1.12.12", 'ontology': 'cl', 'label': 'experimentally modified cell in vitro'}, references=None, vector={}, collection='Ontology_database_agent_test1')]'
# 2025-04-17 15:36:07,521 - utils.utils - INFO - [{'class_uri': 'http://purl.obolibrary.org/obo/GO_0048869', 'all_synonyms_combined': None, 'definition': 'A biological process whose specific outcome is the progression of a cell over time from an initial condition to a later condition.', 'class_id': 'GO_0048869', 'ontology': 'go', 'label': 'cellular developmental process'}, {'definition': "The specific movement from place to place of an organism in response to external or internal stimuli. Locomotion of a whole organism in a manner dependent upon some combination of that organism's internal state and external conditions.", 'all_synonyms_combined': None, 'class_id': 'GO_0007626', 'class_uri': 'http://purl.obolibrary.org/obo/GO_0007626', 'ontology': 'go', 'label': 'locomotory behavior'}, {'class_uri': 'http://purl.obolibrary.org/obo/CL_0000578', 'all_synonyms_combined': None, 'class_id': 'CL_0000578', 'definition': "This class has been re-labeled to imply reference only to in vitro experimentally modified cells, similarly, the definition has been slightly updated to reflect this. 'experimentally modified cell' refers only to cells in vitro, and not modified in vivo/in environment cells. There is currently no class representing unmodified in vitro cells (other than the parent 'cell in vitro'), or a class representing modified native cells. More granular subclassing of experimentally modified cell can be found in ReO. MHB 1.12.12", 'ontology': 'cl', 'label': 'experimentally modified cell in vitro'}]
# 2025-04-17 15:36:07,539 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/meta "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,646 - httpx - INFO - HTTP Request: GET https://pypi.org/pypi/weaviate-client/json "HTTP/1.1 200 OK"
# 2025-04-17 15:36:07,698 - utils.utils - INFO - ✅ Successfully connected to Weaviate
# 2025-04-17 15:36:07,707 - httpx - INFO - HTTP Request: GET http://localhost:8080/v1/schema/Ontology_database_agent_test1 "HTTP/1.1 200 OK"
# ...
#
# 🚀 Crew: crew
# └── 📋 Task: 96ca3dbe-7b67-4402-89db-b31da56c5f12
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Human feedback
#         processor Agent
#
#             Status: In Progress
#         └── 🧠 Thinking...
#
# 15:37:17 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= openai/gpt-4o-2024-11-20; provider = openrouter
# 2025-04-17 15:37:17,538 - LiteLLM - INFO -
# LiteLLM completion() model= openai/gpt-4o-2024-11-20; provider = openrouter
# 2025-04-17 15:37:17,830 - httpx - INFO - HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# 15:38:04 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-17 15:38:04,155 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 🚀 Crew: crew
# └── 📋 Task: 96ca3dbe-7b67-4402-89db-b31da56c5f12
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Human feedback
#         processor Agent
#
#             Status: In Progress
#
#
#
# # Agent: Neuroscience Named Entity Recognition (NER) Human feedback processor Agent
# ## Final Answer:
# {
#   "judged_structured_information": {
#     "ANIMAL_SPECIES": [],
#     "ANATOMICAL_REGIONS": [
#       {
#         "entity": "hippocampus",
#         "label": "ANATOMICAL_REGION",
#         "ontology_id": "UBERON:0001954",
#         "ontology_label": "hippocampus",
#         "sentence": "Among regions associated with navigation, the hippocampus is the most well studied.",
#         "start": 37,
#         "end": 47,
#         "remark": "alignment is based on the search result i.e., knowledge source. High confidence due to exact match with ontology information.",
#         "paper_location": "introduction",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus",
#         "judge_score": 1.0
#       },
#       {
#         "entity": "posterior hippocampus",
#         "label": "ANATOMICAL_REGION",
#         "ontology_id": null,
#         "ontology_label": null,
#         "sentence": "Narrowly tuned neurons were more prevalent in the posterior hippocampus and encoded position more efficiently.",
#         "start": 48,
#         "end": 70,
#         "remark": "alignment is not based on the search result i.e., knowledge source as the entity is not present in knowledge source. Moderate confidence as it represents a specific subregion but lacks ontology alignment. No changes required as it correctly represents entity alignment with moderate confidence.",
#         "paper_location": "abstract",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus",
#         "judge_score": 0.6
#       },
#       {
#         "entity": "anterior hippocampus",
#         "label": "ANATOMICAL_REGION",
#         "ontology_id": null,
#         "ontology_label": null,
#         "sentence": "Others, which were found in both anterior and posterior hippocampus, had broad tuning functions.",
#         "start": 41,
#         "end": 61,
#         "remark": "alignment is not based on the search result i.e., knowledge source as the entity is not present in knowledge source. Moderate confidence as it represents a specific subregion but lacks ontology alignment. No changes required as it correctly represents entity alignment with moderate confidence.",
#         "paper_location": "abstract",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus",
#         "judge_score": 0.6
#       }
#     ],
#     "EXPERIMENTAL_CONDITIONS": [
#       {
#         "entity": "joystick-controlled continuous prey-pursuit task",
#         "label": "EXPERIMENTAL_CONDITION",
#         "ontology_id": null,
#         "ontology_label": null,
#         "sentence": "To understand how this tracking is implemented neurally, we examined responses of hippocampal neurons while humans performed a joystick-controlled continuous prey-pursuit task involving two simultaneously fleeing prey (and, in some cases, a predator) in a virtual open field.",
#         "start": 79,
#         "end": 128,
#         "remark": "alignment is not based on the search result i.e., knowledge source as the entity is not present in knowledge source. Low confidence due to lack of ontology alignment and precise definition. No changes required as it correctly captures low-confidence experimental condition with appropriate score.",
#         "paper_location": "abstract",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus",
#         "judge_score": 0.4
#       },
#       {
#         "entity": "virtual pursuit task",
#         "label": "EXPERIMENTAL_CONDITION",
#         "ontology_id": null,
#         "ontology_label": null,
#         "sentence": "We recorded populations of neurons in the hippocampus in thirteen humans performing a virtual pursuit task with two prey and (in a subset of participants) a predator.",
#         "start": 72,
#         "end": 93,
#         "remark": "alignment is not based on the search result i.e., knowledge source as the entity is not present in knowledge source. Low confidence due to lack of ontology alignment and precise definition. No changes required as it correctly captures low-confidence experimental condition with appropriate score.",
#         "paper_location": "introduction",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus",
#         "judge_score": 0.4
#       },
#       {
#         "entity": "prey-pursuit task",
#         "label": "EXPERIMENTAL_CONDITION",
#         "ontology_id": null,
#         "ontology_label": null,
#         "sentence": "Human participants (n=13) performed the prey-pursuit task.",
#         "start": 40,
#         "end": 57,
#         "remark": "alignment is not based on the search result i.e., knowledge source as the entity is not present in knowledge source. Low confidence due to lack of ontology alignment and precise definition. No changes required as it correctly captures low-confidence experimental condition with appropriate score.",
#         "paper_location": "prey pursuit in humans",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus",
#         "judge_score": 0.4
#       }
#     ],
#     "CELL_TYPES": [
#       {
#         "entity": "place cells",
#         "label": "CELL_TYPE",
#         "ontology_id": "CL:0000676",
#         "ontology_label": "place cell",
#         "sentence": "The hippocampus contains place cells that track the allocentric position of the self in physical space.",
#         "start": 25,
#         "end": 36,
#         "remark": "alignment is based on the search result i.e., knowledge source. High confidence due to exact match with ontology information. No changes required as it correctly represents high-confidence cell type alignment.",
#         "paper_location": "introduction",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus",
#         "judge_score": 1.0
#       },
#       {
#         "entity": "social place cells",
#         "label": "CELL_TYPE",
#         "ontology_id": null,
#         "ontology_label": null,
#         "sentence": "These include neurons that are tuned to positions of external goals and social place cells that track the positions of other agents.",
#         "start": 91,
#         "end": 108,
#         "remark": "alignment is not based on the search result i.e., knowledge source as the entity is not present in knowledge source. Moderate confidence as it represents a valid but unaligned concept. No changes required as it correctly captures moderate-confidence cell type alignment.",
#         "paper_location": "introduction",
#         "paper_title": "Independent Continuous Tracking of Multiple Agents in the Human Hippocampus",
#         "judge_score": 0.7
#       }
#     ]
#   }
# }
#
#
# 2025-04-17 15:38:04,351 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 🚀 Crew: crew
# └── 📋 Task: 96ca3dbe-7b67-4402-89db-b31da56c5f12
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Human feedback
#         processor Agent
#
#             Status: In Progress
#         └── 🧠 Thinking...
#
# 15:38:04 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= openai/gpt-4o-2024-11-20; provider = openrouter
# 2025-04-17 15:38:04,375 - LiteLLM - INFO -
# LiteLLM completion() model= openai/gpt-4o-2024-11-20; provider = openrouter
# 2025-04-17 15:38:04,621 - httpx - INFO - HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# 15:38:13 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-17 15:38:13,970 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 🚀 Crew: crew
# └── 📋 Task: 96ca3dbe-7b67-4402-89db-b31da56c5f12
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Human feedback
#         processor Agent
#
#             Status: In Progress
#
# 2025-04-17 15:38:14,029 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:38:14,050 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:38:14,066 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:38:14,082 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:38:14,108 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:38:14,123 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:38:14,140 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-17 15:38:14,155 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 🚀 Crew: crew
# └── 📋 Task: 96ca3dbe-7b67-4402-89db-b31da56c5f12
#        Status: Executing Task...
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Human feedback
#         processor Agent
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# └── 📋 Task: 96ca3dbe-7b67-4402-89db-b31da56c5f12
#        Assigned to: Neuroscience Named Entity Recognition (NER) Human feedback
#     processor Agent
#
#        Status: ✅ Completed
#     └── 🤖 Agent: Neuroscience Named Entity Recognition (NER) Human feedback
#         processor Agent
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 96ca3dbe-7b67-4402-89db-b31da56c5f12                                  │
# │  Agent: Neuroscience Named Entity Recognition (NER) Human feedback           │
# │  processor Agent                                                             │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: f820f742-84c8-48a1-bd37-d6c8394d7597                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 2025-04-17 15:38:14,169 - structsense.app - INFO - Updated shared state: feedback_terms
#
# ================================================================================
# HUMAN FEEDBACK REQUIRED FOR: human_feedback_processing (Agent: humanfeedback_agent)
# ================================================================================
# Data contains keys: judged_structured_information
#
# Options:
# 1. Approve and continue
# 2. View agent output
# 3. Modify
# 4. Abort
# Enter choice (1/2/3/4):
