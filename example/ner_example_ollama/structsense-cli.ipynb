# %% [markdown]
# # Install structsense and makesure GROBID is running. Use the command below.
#
# ```shell
# docker pull lfoppiano/grobid:0.8.0
# docker run --init -p 8070:8070 -e JAVA_OPTS="-XX:+UseZGC" lfoppiano/grobid:0.8.0
# ```

# %%
# !pip install structsense --quiet

# %%
# !structsense-cli
# Out:
# Usage: structsense-cli [OPTIONS] COMMAND [ARGS]...
#
#   CLI commands for the Structsense Framework application
#
# Options:
#   --help  Show this message and exit.
#
# Commands:
#   extract  Extract the terms along with sentence.

# %%
# !structsense-cli extract --help
# Out:
# Usage: structsense-cli extract [OPTIONS]
#
#   Extract the terms along with sentence.
#
# Options:
#   --agentconfig TEXT      Path to the agent configuration in YAML file format
#                           or dictionary  [required]
#   --taskconfig TEXT       Path to the agent task configuration in YAML format
#                           or or dictionary  [required]
#   --embedderconfig TEXT   Path to the embedding configuration in YAML format
#                           or or dictionary  [required]
#   --flowconfig TEXT       Path to the flow configuration in YAML format or or
#                           dictionary. The flow configuration describes the
#                           flow of the agent.  [required]
#   --knowledgeconfig TEXT  Path to the configuration in YAML format or or
#                           dictionary that specify the search knowledge search
#                           key.
#   --source TEXT           The source—whether a file (text or PDF), a folder,
#                           or a text string.  [required]
#   --help                  Show this message and exit.

# %% [markdown]
# # Set Environment Variables

# %%
# %env ENABLE_WEIGHTSANDBIAS=false
# %env ENABLE_MLFLOW=false
# %env ENABLE_KG_SOURCE=false
# %env ONTOLOGY_DATABASE=Ontology_database_agent_test #note this is my local vectordatabase name, we need this because ENABLE_KG_SOURCE=true
# %env WEAVIATE_API_KEY="XG!mUEC&io" #note this is my local vectordatabase key
# %env OLLAMA_API_ENDPOINT=http://host.docker.internal:11434 #note this is my local vectordatabase name
# %env OLLAMA_MODEL=nomic-embed-text #note this is my local vectordatabase name
# Out:
# env: ENABLE_WEIGHTSANDBIAS=false
# env: ENABLE_MLFLOW=false
# env: ENABLE_KG_SOURCE=false
# env: ONTOLOGY_DATABASE=Ontology_database_agent_test #note this is my local vectordatabase name, we need this because ENABLE_KG_SOURCE=true
# env: WEAVIATE_API_KEY="XFG!NQmUVEC&8" #note this is my local vectordatabase key
# env: OLLAMA_API_ENDPOINT=http://host.docker.internal:11434 #note this is my local vectordatabase name
# env: OLLAMA_MODEL=nomic-embed-text #note this is my local vectordatabase name

# %%
# !ls
# Out:
# crew_memory           ner_config            structsense-cli.ipynb

# %%
# !ls ner_config/
# Out:
# embedding.yaml                 ner_task.yaml
# flow_ner.yaml                  search_ontology_knowledge.yaml
# ner_agent.yaml

# %%
! cat ner_config/ner_agent.yaml
# Out:
# agents:
#   - id: extractor_agent
#     output_variable: extracted_info
#     role: >
#       Neuroscience Named Entity Recognition (NER) Extractor Agent
#     goal: >
#       Perform Named Entity Recognition (NER) on neuroscience {literature} and return structured JSON output.
#     backstory: >
#       You are an AI assistant specialized in processing neuroscience and who do not hallucinate.
#       Your expertise includes recognizing and categorizing named entities such as anatomical regions, experimental conditions, and cell types.
#       Your responses strictly adhere to JSON format, ensuring accurate and structured data extraction for downstream applications.
#     llm:
#       model: ollama/deepseek-r1:14b
#       base_url: http://localhost:11434
#       seed: 53
#
#   - id: alignment_agent
#     output_variable: aligned_structured_terms
#     role: >
#       Neuroscience Named Entity Recognition (NER) Concept Alignment Agent
#     goal: >
#       Perform concept alignment to the extracted Named Entity Recognition (NER) by extractor_agent {extracted_info} and return structured JSON output.
#     backstory: >
#       You are an AI assistant specialized in processing neuroscience concept alignment with structured models, i.e., ontologies or schemas and who do not hallucinate.
#       Your expertise includes recognizing and categorizing extracted named entities such as anatomical regions, experimental conditions, and cell types and aligning the recognized named entities such as cell types with corresponding ontological terms.
#       Your responses strictly adhere to JSON format, ensuring accurate and structured data extraction for downstream applications.
#     llm:
#       model: ollama/deepseek-r1:14b
#       base_url: http://localhost:11434
#       seed: 53
#
#   - id: judge_agent
#     output_variable: aligned_judged_terms
#     role: >
#       Neuroscience Named Entity Recognition (NER) Judge Agent
#     goal: >
#       Evaluate the {aligned_structured_terms} based on predefined criteria and generate a structured JSON output reflecting the assessment results.
#     backstory: >
#       You are an AI assistant with expert knowledge in neuroscience and structured models, i.e., ontologies or schemas, and someone who does not hallucinate.
#       Your task is to evaluate the {aligned_structured_terms} based on the accuracy and quality of the alignment.
#       Assign the score between 0-1 with 1 being the highest score of your evaluation.
#       Your responses strictly adhere to JSON format, ensuring accurate and structured data extraction for downstream applications.
#     llm:
#       model: ollama/deepseek-r1:14b
#       base_url: http://localhost:11434
#       seed: 53

# %% [markdown]
# # Extract from a PDF file (with knowledge source)
#
# Input: https://www.biorxiv.org/content/10.1101/2025.03.06.641914v1

# %%
# !structsense-cli extract --agentconfig ner_config/ner_agent.yaml --taskconfig ner_config/ner_task.yaml --embedderconfig ner_config/embedding.yaml --flowconfig ner_config/flow_ner.yaml --knowledgeconfig ner_config/search_ontology_knowledge.yaml --source test.pdf
# Out:
# 2025-04-02 15:33:41,800 - structsense.cli - INFO - Processing source: test.pdf with agent config: ner_config/ner_agent.yaml, task config: ner_config/ner_task.yaml, embedderconfig: ner_config/embedding.yaml, flowconfig: ner_config/flow_ner.yaml, knowledgeconfig: ner_config/search_ontology_knowledge.yaml
# Processing source: test.pdf with agent config: ner_config/ner_agent.yaml, task config: ner_config/ner_task.yaml, embedderconfig: ner_config/embedding.yaml knowledgeconfig: ner_config/search_ontology_knowledge.yaml flowconfig: ner_config/flow_ner.yaml
# 2025-04-02 15:33:41,801 - utils.utils - INFO - Trying paths: ['test.pdf', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/test.pdf', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/test.pdf', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/test.pdf']
# 2025-04-02 15:33:41,801 - utils.utils - INFO - Using path: test.pdf
# 2025-04-02 15:33:41,801 - utils.utils - INFO - Processing single file: test.pdf
# 2025-04-02 15:33:46,033 - utils.utils - INFO - Successfully extracted 17 sections
# ╭─────────────────────────────── Flow Execution ───────────────────────────────╮
# │                                                                              │
# │  Starting Flow Execution                                                     │
# │  Name: StructSenseFlow                                                       │
# │  ID: 5931eff8-4423-41a8-a6e8-05e70ed871ee                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 2025-04-02 15:33:46,038 - utils.utils - INFO - Trying config paths: ['ner_config/ner_agent.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/ner_agent.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/ner_agent.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/ner_agent.yaml']
# 2025-04-02 15:33:46,048 - utils.utils - INFO - file processing - <_io.TextIOWrapper name='ner_config/ner_agent.yaml' mode='r' encoding='utf-8'>, type: agent
# 2025-04-02 15:33:46,049 - utils.utils - INFO - Trying config paths: ['ner_config/ner_task.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/ner_task.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/ner_task.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/ner_task.yaml']
# 2025-04-02 15:33:46,066 - utils.utils - INFO - file processing - <_io.TextIOWrapper name='ner_config/ner_task.yaml' mode='r' encoding='utf-8'>, type: task
# 2025-04-02 15:33:46,066 - utils.utils - INFO - Trying config paths: ['ner_config/embedding.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/embedding.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/embedding.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/embedding.yaml']
# 2025-04-02 15:33:46,067 - utils.utils - INFO - file processing - <_io.TextIOWrapper name='ner_config/embedding.yaml' mode='r' encoding='utf-8'>, type: embedder
# 2025-04-02 15:33:46,068 - utils.utils - INFO - Trying config paths: ['ner_config/flow_ner.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/flow_ner.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/flow_ner.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/flow_ner.yaml']
# 2025-04-02 15:33:46,071 - utils.utils - INFO - file processing - <_io.TextIOWrapper name='ner_config/flow_ner.yaml' mode='r' encoding='utf-8'>, type: flow
# 2025-04-02 15:33:46,072 - utils.utils - INFO - Trying config paths: ['ner_config/search_ontology_knowledge.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/search_ontology_knowledge.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/search_ontology_knowledge.yaml', '/Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/ner_example_ollama/ner_config/search_ontology_knowledge.yaml']
# 2025-04-02 15:33:46,072 - utils.utils - INFO - file processing - <_io.TextIOWrapper name='ner_config/search_ontology_knowledge.yaml' mode='r' encoding='utf-8'>, type: knowledge
# 2025-04-02 15:33:46,102 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 🌊 Flow: StructSenseFlow
#     ID: 5931eff8-4423-41a8-a6e8-05e70ed871ee
# └── 🧠 Starting Flow...
#
#  Flow started with ID: 5931eff8-4423-41a8-a6e8-05e70ed871ee
# 2025-04-02 15:33:46,436 - crewai.flow.flow - INFO - Flow started with ID: 5931eff8-4423-41a8-a6e8-05e70ed871ee
# 🌊 Flow: StructSenseFlow
#     ID: 5931eff8-4423-41a8-a6e8-05e70ed871ee
# ├── 🧠 Starting Flow...
# └── 🔄 Running: kickoff_flow
#
# 2025-04-02 15:33:46,438 - structsense.app - INFO - Running step: extracted_structured_information
# 2025-04-02 15:33:47,202 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-02 15:33:47,960 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# # Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
# ## Task: From the given literature extract named entities from neuroscience statements.  A named entity is anything that can be referred to with a proper name.  Some common named entities in neuroscience articles are animal species (e.g., mouse, drosophila, zebrafish), anatomical regions (e.g., neocortex, mushroom body, cerebellum), experimental conditions (e.g., control, tetrodotoxin treatment, Scn1a knockout), and cell types (e.g., pyramidal neuron, direction-sensitive mechanoreceptor, oligodendrocyte)
# Literature: {'metadata': {'title': 'Independent Continuous Tracking of Multiple Agents in the Human Hippocampus', 'authors': ['Assia Chericoni', 'Justin M Fine', 'Ana G Chavez', 'Melissa C Franch', 'Elizabeth A Mickiewicz', 'Raissa K Mathura', 'Joshua Adkinson', 'Eleonora Bartoli', 'Joshua Jacobs', 'Nicole R Provenza', 'Andrew J Watrous', 'Seng Bum', 'Michael Yoo', 'Sameer A Sheth', 'Benjamin Y Hayden'], 'abstract': 'The pursuit of fleeing prey is a core element of many species behavioral repertoires. It poses the difficult problem of continuous tracking of multiple agents, including both self and others. To understand how this tracking is implemented neurally, we examined responses of hippocampal neurons while humans performed a joystick-controlled continuous prey-pursuit task involving two simultaneously fleeing prey (and, in some cases, a predator) in a virtual open field. We found neural maps encoding the positions of all the agents. All maps were multiplexed in single neurons and were disambiguated by the use of the population coding principle of semiorthogonal subspaces, which can facilitate cross-agent generalization. Some neurons, more common in the posterior hippocampus, had narrow tuning functions reminiscent of place cells, lower firing rates, and high information per spike; others, which were found in both anterior and posterior hippocampus, had broad tuning functions, higher firing rates, and less information per spike. Semi-orthogonalization was selectively associated with the broadly tuned neurons. These results suggest an answer to the problem of navigational individuation, that is, how mapping codes can distinguish different agents, and establish the neuronavigational foundations of pursuit.', 'publication_date': ''}, 'sections': [{'heading': 'INTRODUCTION', 'content': "['Pursuit is a foraging behavior involving continuous and interactive navigation with the goal of catching a fleeing prey while avoiding predators (Fabian et al., 2018;Olberg et al., 2000;Stephens  Krebs, 1986;Ydenberg  Dill, 1986). It is an archetypal example of continuous decision-making, in which choice and control are deployed simultaneously (Burge et al., 2025;Cisek and Kalaska, 2010;Gordon et al., 2021;Merel et al., 2015;Yoo et al., 2021A). Moment to moment choices during pursuit require tracking the locations of multiple agents at the same time, including the self, pursued prey, and unpursued prey, and navigating towards interception loci.', 'Among regions associated with navigation, the hippocampus is the most well studied (Chersi and Burgess, 2015;Ekstrom et al., 2018;Epstein et al., 2017;Kunz et al., 2021;Maguire et al., 2006;Nyberg et al., 2022;OKeefe and Dostrovsky, 1971;Suthana et al., 2009). The hippocampus contains place cells that track the allocentric position of the self in physical space (Ekstrom et al., 2003;Jacobs et al., 2010;Miller et al., 2013;OKeefe et al., 1998;Wilson and McNaughton, 1993) and virtual space (Harvey et al., 2009;Mackay et al., 2024). The hippocampus also has a variety of other neurons relevant to pursuit (Behrens et al., 2018). These include neurons that are tuned to positions of external (physical) goals (Brown et al., 2016;Gauthier and Tank, 2018;Kunz et al., 2021;Poucet and Hok, 2017;Watrous et al., 2018), and social place cells that track the positions of other agents (Danjo et al., 2018;Forli and Yartsev, 2023;Omer et al., 2018;Rao et al., 2019;Stangl et al., 2021;Zang et al., 2024). The collective existence of these neurons indicates that the hippocampus contains the basic ingredients to track both self and prey in the course of pursuit. However, it does not give insight into how the brain solve the problem of disambiguating representations when faced with multiple distinct agents.', 'The need to distinguish self from others, and to distinguish multiple others, means that the brain must solve the individuation problem. In short, the brain needs a mechanism to know which agent a neurons responses r ...
#
# 15:33:48 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:33:48,013 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:35:20,451 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:35:20 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:35:20,565 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:35:20,615 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:35:20,616 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 15:35:20 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:35:20,633 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:35:20,682 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:35:20,704 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:36:46,441 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:36:46 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:36:46,534 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
#
#
# # Agent: Neuroscience Named Entity Recognition (NER) Extractor Agent
# ## Final Answer:
# {
#   "extracted_terms": {
#     "1": [
#       {
#         "entity": "mouse",
#         "label": "ANIMAL_SPECIES",
#         "sentence": "These particles were visualized by fluorescent immunohistochemistry using mouse monoclonal anti-human myelin basic protein (MBPh) antibody (clone SMI-99).",
#         "start": 79,
#         "end": 84,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "2": [
#       {
#         "entity": "oligodendrocyte",
#         "label": "CELL_TYPE",
#         "sentence": "Individual oligodendrocytes provide, on average, 16 near axons with single myelin segments about 200 µm in length (Butt and Ransom, 1993).",
#         "start": 14,
#         "end": 29,
#         "paper_location": "discussion",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "3": [
#       {
#         "entity": "cerebellum",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Myelin basic protein, human (MBPh) The mouse monoclonal antibody against the human myelin basic protein (clone SMI-99; Covance, Princeton, NJ) detects 4 bands between 14 and 21 kDa, corresponding to 4 myelin basic protein (MBP) isoforms on immunoblots of the mouse cerebellum (Dyer et al.).",
#         "start": 293,
#         "end": 303,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ]
#   }
# }
#
#
# 2025-04-02 15:36:46,557 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:36:46,589 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:36:46,691 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# /Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/.structsense_env/lib/python3.11/site-packages/chromadb/types.py:144: PydanticDeprecatedSince211: Accessing this attribute on the instance is deprecated, and will be removed in Pydantic V3. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   return self.model_fields  # pydantic 2.x
# 2025-04-02 15:36:46,738 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:36:46,751 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 15:36:46 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:36:46,756 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:38:21,387 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:38:21 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:38:21,434 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:38:21,473 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:38:21,473 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 15:38:21 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:38:21,482 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:38:21,507 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:39:55,360 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:39:55 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:39:55,409 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:39:55,446 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:39:55,447 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 15:39:55 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:39:55,454 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:39:55,485 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:41:28,950 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:41:28 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:41:28,998 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# Failed to add to long term memory: Failed to convert text into a Pydantic model due to error: 'NoneType' object has no attribute 'function_calling_llm'
# 2025-04-02 15:41:29,028 - structsense.app - INFO - Running step: align_structured_information
# 2025-04-02 15:41:29,060 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:41:29,095 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:41:29,276 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-02 15:41:29,347 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# # Agent: Neuroscience Named Entity Recognition (NER) Concept Alignment Agent
# ## Task: Take the output of extractor_agent {
#   "extracted_terms": {
#     "1": [
#       {
#         "entity": "mouse",
#         "label": "ANIMAL_SPECIES",
#         "sentence": "These particles were visualized by fluorescent immunohistochemistry using mouse monoclonal anti-human myelin basic protein (MBPh) antibody (clone SMI-99).",
#         "start": 79,
#         "end": 84,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "2": [
#       {
#         "entity": "oligodendrocyte",
#         "label": "CELL_TYPE",
#         "sentence": "Individual oligodendrocytes provide, on average, 16 near axons with single myelin segments about 200 µm in length (Butt and Ransom, 1993).",
#         "start": 14,
#         "end": 29,
#         "paper_location": "discussion",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "3": [
#       {
#         "entity": "cerebellum",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Myelin basic protein, human (MBPh) The mouse monoclonal antibody against the human myelin basic protein (clone SMI-99; Covance, Princeton, NJ) detects 4 bands between 14 and 21 kDa, corresponding to 4 myelin basic protein (MBP) isoforms on immunoblots of the mouse cerebellum (Dyer et al.).",
#         "start": 293,
#         "end": 303,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ]
#   }
# } as input and perform the concept alignment using the ontological concepts.  A concept alignment is anything where you align the given entity to the matching concept aka class from a ontology or a schema.
#
# 15:41:29 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:41:29,365 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:43:02,934 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:43:02 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:43:02,976 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 15:43:02 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:43:02,983 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:43:03,017 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:43:03,037 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:44:22,403 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:44:22 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:44:22,430 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
#
#
# # Agent: Neuroscience Named Entity Recognition (NER) Concept Alignment Agent
# ## Final Answer:
# {
#   "extracted_terms": {
#     "1": [
#       {
#         "entity": "mouse",
#         "label": "ANIMAL_SPECIES",
#         "sentence": "These particles were visualized by fluorescent immunohistochemistry using mouse monoclonal anti-human myelin basic protein (MBPh) antibody (clone SMI-99).",
#         "start": 79,
#         "end": 84,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "2": [
#       {
#         "entity": "oligodendrocyte",
#         "label": "CELL_TYPE",
#         "sentence": "Individual oligodendrocytes provide, on average, 16 nearby axons with single myelin segments about 200 µm in length (Butt and Ransom, 1993).",
#         "start": 14,
#         "end": 29,
#         "paper_location": "discussion",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "3": [
#       {
#         "entity": "cerebellum",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Myelin basic protein, human (MBPh) The mouse monoclonal antibody against the human myelin basic protein (clone SMI-99; Covance, Princeton, NJ) detects 4 bands between 14 and 21 kDa, corresponding to 4 myelin basic protein (MBP) isoforms on immunoblots of the mouse cerebellum (Dyer et al.).",
#         "start": 293,
#         "end": 303,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ]
#   }
# }
#
#
# 2025-04-02 15:44:22,454 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:44:22,477 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:44:22,544 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# /Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/.structsense_env/lib/python3.11/site-packages/chromadb/types.py:144: PydanticDeprecatedSince211: Accessing this attribute on the instance is deprecated, and will be removed in Pydantic V3. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   return self.model_fields  # pydantic 2.x
# 2025-04-02 15:44:22,586 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:44:22,603 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 15:44:22 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:44:22,608 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:45:17,364 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:45:17 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:45:17,385 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:45:17,415 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:45:17,416 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 15:45:17 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:45:17,428 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:45:17,479 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:46:11,289 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:46:11 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:46:11,306 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:46:11,326 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:46:11,327 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 15:46:11 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:46:11,337 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:46:11,359 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:47:05,086 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:47:05 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:47:05,104 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# Failed to add to long term memory: Failed to convert text into a Pydantic model due to error: 'NoneType' object has no attribute 'function_calling_llm'
# 2025-04-02 15:47:05,115 - structsense.app - INFO - Running step: judge_alignment
# 2025-04-02 15:47:05,125 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:47:05,143 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:47:05,317 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-02 15:47:05,494 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# # Agent: Neuroscience Named Entity Recognition (NER) Judge Agent
# ## Task: Take the output of alignment agent {
#   "extracted_terms": {
#     "1": [
#       {
#         "entity": "mouse",
#         "label": "ANIMAL_SPECIES",
#         "sentence": "These particles were visualized by fluorescent immunohistochemistry using mouse monoclonal anti-human myelin basic protein (MBPh) antibody (clone SMI-99).",
#         "start": 79,
#         "end": 84,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "2": [
#       {
#         "entity": "oligodendrocyte",
#         "label": "CELL_TYPE",
#         "sentence": "Individual oligodendrocytes provide, on average, 16 nearby axons with single myelin segments about 200 µm in length (Butt and Ransom, 1993).",
#         "start": 14,
#         "end": 29,
#         "paper_location": "discussion",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "3": [
#       {
#         "entity": "cerebellum",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Myelin basic protein, human (MBPh) The mouse monoclonal antibody against the human myelin basic protein (clone SMI-99; Covance, Princeton, NJ) detects 4 bands between 14 and 21 kDa, corresponding to 4 myelin basic protein (MBP) isoforms on immunoblots of the mouse cerebellum (Dyer et al.).",
#         "start": 293,
#         "end": 303,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ]
#   }
# } as input and perform the following evaluation:  1. Assess the quality and accuracy of the alignment with the ontology or schema in {
#   "extracted_terms": {
#     "1": [
#       {
#         "entity": "mouse",
#         "label": "ANIMAL_SPECIES",
#         "sentence": "These particles were visualized by fluorescent immunohistochemistry using mouse monoclonal anti-human myelin basic protein (MBPh) antibody (clone SMI-99).",
#         "start": 79,
#         "end": 84,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "2": [
#       {
#         "entity": "oligodendrocyte",
#         "label": "CELL_TYPE",
#         "sentence": "Individual oligodendrocytes provide, on average, 16 nearby axons with single myelin segments about 200 µm in length (Butt and Ransom, 1993).",
#         "start": 14,
#         "end": 29,
#         "paper_location": "discussion",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "3": [
#       {
#         "entity": "cerebellum",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Myelin basic protein, human (MBPh) The mouse monoclonal antibody against the human myelin basic protein (clone SMI-99; Covance, Princeton, NJ) detects 4 bands between 14 and 21 kDa, corresponding to 4 myelin basic protein (MBP) isoforms on immunoblots of the mouse cerebellum (Dyer et al.).",
#         "start": 293,
#         "end": 303,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ]
#   }
# }. 2. Assign a score between 0 and 1 as a judge_score. 3. Update the {
#   "extracted_terms": {
#     "1": [
#       {
#         "entity": "mouse",
#         "label": "ANIMAL_SPECIES",
#         "sentence": "These particles were visualized by fluorescent immunohistochemistry using mouse monoclonal anti-human myelin basic protein (MBPh) antibody (clone SMI-99).",
#         "start": 79,
#         "end": 84,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "2": [
#       {
#         "entity": "oligodendrocyte",
#         "label": "CELL_TYPE",
#         "sentence": "Individual oligodendrocytes provide, on average, 16 nearby axons with single myelin segments about 200 µm in length (Butt and Ransom, 1993).",
#         "start": 14,
#         "end": 29,
#         "paper_location": "discussion",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "3": [
#       {
#         "entity": "cerebellum",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Myelin basic protein, human (MBPh) The mouse monoclonal antibody against the human myelin basic protein (clone SMI-99; Covance, Princeton, NJ) detects 4 bands between 14 and 21 kDa, corresponding to 4 myelin basic protein (MBP) isoforms on immunoblots of the mouse cerebellum (Dyer et al.).",
#         "start": 293,
#         "end": 303,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ]
#   }
# } adding the judge_score.
#
# 15:47:05 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:47:05,521 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:48:56,040 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:48:56 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:48:56,074 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
# 15:48:56 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:48:56,082 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:48:56,116 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:48:56,178 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:50:28,564 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
# 15:50:28 - LiteLLM:INFO: utils.py:1084 - Wrapper: Completed Call, calling success_handler
# 2025-04-02 15:50:28,600 - LiteLLM - INFO - Wrapper: Completed Call, calling success_handler
#
#
# # Agent: Neuroscience Named Entity Recognition (NER) Judge Agent
# ## Final Answer:
# ```json
# {
#   "extracted_terms": {
#     "1": [
#       {
#         "entity": "mouse",
#         "label": "ANIMAL_SPECIES",
#         "sentence": "These particles were visualized by fluorescent immunohistochemistry using mouse monoclonal anti-human myelin basic protein (MBPh) antibody (clone SMI-99).",
#         "start": 79,
#         "end": 84,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "2": [
#       {
#         "entity": "oligodendrocyte",
#         "label": "CELL_TYPE",
#         "sentence": "Individual oligodendrocytes provide, on average, 16 near axons with single myelin segments about 200 µm in length (Butt and Ransom, 1993).",
#         "start": 14,
#         "end": 29,
#         "paper_location": "discussion",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ],
#     "3": [
#       {
#         "entity": "cerebellum",
#         "label": "ANATOMICAL_REGION",
#         "sentence": "Myelin basic protein, human (MBPh) The mouse monoclonal antibody against the human myelin basic protein (clone SMI-99; Covance, Princeton, NJ) detects 4 bands between 14 and 21 kDa, corresponding to 4 myelin basic protein (MBP) isoforms on immunoblots of the mouse cerebellum (Dyer et al.).",
#         "start": 293,
#         "end": 303,
#         "paper_location": "methods",
#         "paper_title": "Concentration of myelin debris-like myelin basic protein-immunoreactive particles in the distal (anterior)-most part of the myelinated region in the normal rat optic nerve",
#         "doi": "10.1101/2025.03.19.643597"
#       }
#     ]
#   }
# }
# ```
#
#
# 2025-04-02 15:50:28,629 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:50:28,650 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:50:28,771 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# /Users/tekrajchhetri/Documents/brainypedia_codes_design/crew_ner_framework/structsense/example/.structsense_env/lib/python3.11/site-packages/chromadb/types.py:144: PydanticDeprecatedSince211: Accessing this attribute on the instance is deprecated, and will be removed in Pydantic V3. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   return self.model_fields  # pydantic 2.x
# 2025-04-02 15:50:28,814 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2025-04-02 15:50:28,833 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 15:50:28 - LiteLLM:INFO: utils.py:2896 -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
# 2025-04-02 15:50:28,842 - LiteLLM - INFO -
# LiteLLM completion() model= deepseek-r1:14b; provider = ollama
